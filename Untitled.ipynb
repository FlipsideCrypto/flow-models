# %%
import pandas as pd

# %%
df = pd.read_csv('missing_blocks.csv')

# %%
df["number"] = df.apply(lambda row: [ x for x in range(row["PREV_BLOCK_HEIGHT"] + 1 , row['BLOCK_HEIGHT'])], axis=1)

# %%
df["number"]
# Out:
# 0      [55526169]
# 1      [55855045]
# 2      [55891569]
# 3      [56055814]
# 4      [56082098]
#           ...
# 458    [56181499]
# 459    [56201960]
# 460    [56210148]
# 461    [56233744]
# 462    [56260276]
# Name: number, Length: 463, dtype: object

# %%
unique_numbers = list(set([num for sublist in df['number'] for num in sublist]))

# %%
sorted(unique_numbers)
# Out:
# [12000191,
#  12021794,
#  12023468,
#  13950735,
#  44950119,
#  44950191,
#  47169686,
#  55115130,
#  55115189,
#  55115278,
#  55115288,
#  55115317,
#  55115373,
#  55115426,
#  55115455,
#  55115535,
#  55115564,
#  55115631,
#  55115671,
#  55115721,
#  55115765,
#  55115768,
#  55115817,
#  55115845,
#  55115854,
#  55115872,
#  55115916,
#  55115962,
#  55115994,
#  55116069,
#  55116147,
#  55116326,
#  55116409,
#  55116446,
#  55116498,
#  55116537,
#  55116583,
#  55117189,
#  55117296,
#  55117390,
#  55117430,
#  55117593,
#  55117710,
#  55117965,
#  55118107,
#  55118691,
#  55119128,
#  55119173,
#  55119674,
#  55119772,
#  55119959,
#  55120179,
#  55120217,
#  55120267,
#  55120425,
#  55120476,
#  55120891,
#  55120996,
#  55121356,
#  55121553,
#  55122421,
#  55122808,
#  55123797,
#  55123914,
#  55124182,
#  55126738,
#  55179467,
#  55347066,
#  55406343,
#  55410211,
#  55430729,
#  55469999,
#  55526169,
#  55596579,
#  55600999,
#  55617127,
# ...
